# %%
import pandas as pd  
import numpy as np
import pickle

# %%
std = pd.read_csv("Data\\students.csv")
std
# Out:
#     Student_ID            Name  \
# 0            1      Amit Verma
# 1            2    Rahul Sharma
# 2            3   Ananya Chopra
# 3            4    Ananya Verma
# 4            5  Rohan Kulkarni
# ..         ...             ...
# 95          96      Kavya Nair
# 96          97     Kavya Mehta
# 97          98      Rohan Bose
# 98          99     Priya Verma
# 99         100     Rohan Reddy
#
#                                                Skills Education Experience
# 0   Python, Machine Learning, Cybersecurity, Web D...    M.Tech   5+ years
# 1   Python, Cloud Computing, Java, Web Development...    M.Tech    3 years
# 2                  Java, DevOps, C++, Cloud Computing    B.Tech    2 years
# 3   Machine Learning, Data Science, SQL, DevOps, C...      M.Sc    2 years
# 4         Cloud Computing, SQL, Cybersecurity, DevOps      B.Sc    3 years
# ..                                                ...       ...        ...
# 95  Python, Data Science, Web Development, Cyberse...    M.Tech    2 years
# 96  Machine Learning, Web Development, Cloud Compu...      B.Sc    2 years
# 97  Cybersecurity, DevOps, Web Development, Cloud ...    B.Tech    3 years
# 98              Cybersecurity, C++, Java, DevOps, SQL      M.Sc    3 years
# 99  Cybersecurity, Web Development, Data Science, ...    B.Tech     1 year
#
# [100 rows x 5 columns]

# %%
jobs = pd.read_csv("Data\\jobs.csv")
jobs
# Out:
#     Job_ID    Company                  Job_Role  \
# 0        1      Tesla            Cloud Engineer
# 1        2  Microsoft         Software Engineer
# 2        3    Infosys               ML Engineer
# 3        4     Oracle              Data Analyst
# 4        5  Microsoft            Cloud Engineer
# 5        6     Oracle         Software Engineer
# 6        7     Amazon  Cybersecurity Specialist
# 7        8    Infosys              Data Analyst
# 8        9        TCS               ML Engineer
# 9       10   Facebook         Software Engineer
# 10      11        TCS              Data Analyst
# 11      12     Amazon               ML Engineer
# 12      13      Tesla  Cybersecurity Specialist
# 13      14     Amazon            Cloud Engineer
# 14      15  Microsoft            Cloud Engineer
# 15      16        IBM         Software Engineer
# 16      17     Amazon  Cybersecurity Specialist
# 17      18        IBM              Data Analyst
# 18      19     Amazon         Software Engineer
# 19      20     Google            Cloud Engineer
# 20      21     Amazon            Cloud Engineer
# 21      22        IBM         Software Engineer
# 22      23     Oracle  Cybersecurity Specialist
# 23      24  Microsoft              Data Analyst
# 24      25   Facebook            Cloud Engineer
# 25      26     Google  Cybersecurity Specialist
# 26      27        TCS              Data Analyst
# 27      28     Oracle            Cloud Engineer
# 28      29      Tesla            Cloud Engineer
# 29      30     Amazon              Data Analyst
# 30      31        TCS         Software Engineer
# 31      32        IBM               ML Engineer
# 32      33     Oracle  Cybersecurity Specialist
# 33      34     Amazon            Cloud Engineer
# 34      35     Amazon  Cybersecurity Specialist
# 35      36     Amazon              Data Analyst
# 36      37     Amazon               ML Engineer
# 37      38    Infosys         Software Engineer
# 38      39        IBM         Software Engineer
# 39      40     Amazon              Data Analyst
# 40      41      Tesla  Cybersecurity Specialist
# 41      42   Facebook            Cloud Engineer
# 42      43   Facebook              Data Analyst
# 43      44     Amazon               ML Engineer
# 44      45  Microsoft         Software Engineer
# 45      46      Wipro               ML Engineer
# 46      47   Facebook  Cybersecurity Specialist
# 47      48      Tesla  Cybersecurity Specialist
# 48      49        TCS               ML Engineer
# 49      50      Tesla  Cybersecurity Specialist
#
#                                       Required_Skills Experience_Level
# 0              C++, Machine Learning, Cloud Computing          3 years
# 1                      Cloud Computing, Cybersecurity          Fresher
# 2                                Web Development, C++          2 years
# 3                          Data Science, DevOps, Java          Fresher
# 4                 Cybersecurity, Cloud Computing, SQL         5+ years
# 5                    Cloud Computing, Web Development         5+ years
# 6                                        Java, DevOps         5+ years
# 7                     Data Science, Python, SQL, Java          2 years
# 8                                DevOps, Java, Python         5+ years
# 9             Machine Learning, Cloud Computing, Java          3 years
# 10                              Cybersecurity, Python           1 year
# 11           Cloud Computing, Java, C++, Data Science           1 year
# 12                         Data Science, Java, Python          2 years
# 13     Machine Learning, DevOps, SQL, Web Development         5+ years
# 14                   DevOps, Java, SQL, Cybersecurity           1 year
# 15           Cloud Computing, DevOps, Web Development          2 years
# 16     Python, Cybersecurity, Web Development, DevOps          2 years
# 17                                        DevOps, C++         5+ years
# 18                     SQL, C++, Data Science, Python         5+ years
# 19       Python, Cybersecurity, SQL, Machine Learning          3 years
# 20                                     DevOps, Python           1 year
# 21                                        DevOps, C++          3 years
# 22           Python, Cybersecurity, Data Science, SQL           1 year
# 23                 DevOps, Cloud Computing, Java, C++          Fresher
# 24                     Data Science, SQL, C++, DevOps          Fresher
# 25  Python, Data Science, Machine Learning, Cybers...          3 years
# 26        Cybersecurity, Python, Cloud Computing, C++          3 years
# 27       Java, Python, Cloud Computing, Cybersecurity          3 years
# 28                Java, Data Science, Cloud Computing         5+ years
# 29  Machine Learning, Cybersecurity, Cloud Computi...           1 year
# 30                               SQL, Web Development           1 year
# 31             Cloud Computing, Web Development, Java         5+ years
# 32                     Cloud Computing, Cybersecurity          2 years
# 33        Python, Cybersecurity, Web Development, C++           1 year
# 34                              Java, Web Development           1 year
# 35                       DevOps, Python, Data Science          Fresher
# 36                     Web Development, Cybersecurity          2 years
# 37          Data Science, Java, Machine Learning, C++           1 year
# 38     Python, C++, Cloud Computing, Machine Learning         5+ years
# 39        Python, Cloud Computing, Cybersecurity, C++          Fresher
# 40                            Web Development, DevOps           1 year
# 41       Cybersecurity, Data Science, Web Development           1 year
# 42       DevOps, Cloud Computing, Java, Cybersecurity         5+ years
# 43                              Cybersecurity, Python          2 years
# 44                            Web Development, Python           1 year
# 45              Data Science, Cloud Computing, Python           1 year
# 46    Web Development, Cloud Computing, Cybersecurity          Fresher
# 47                                  SQL, DevOps, Java          Fresher
# 48  Cybersecurity, Web Development, Cloud Computin...           1 year
# 49                               Cloud Computing, C++         5+ years

# %%
applications = pd.read_csv("Data\\applications.csv")
applications
# Out:
#      Student_ID  Job_ID Applied_Company                  Job_Role  \
# 0            69       7          Amazon  Cybersecurity Specialist
# 1            37       9             TCS               ML Engineer
# 2            72      47        Facebook  Cybersecurity Specialist
# 3            60       8         Infosys              Data Analyst
# 4            45      21          Amazon            Cloud Engineer
# ..          ...     ...             ...                       ...
# 195          12       1           Tesla            Cloud Engineer
# 196           9      33          Oracle  Cybersecurity Specialist
# 197          70       7          Amazon  Cybersecurity Specialist
# 198          34      45       Microsoft         Software Engineer
# 199          14      30          Amazon              Data Analyst
#
#     Application_Status
# 0             Rejected
# 1             Rejected
# 2              Pending
# 3              Pending
# 4             Rejected
# ..                 ...
# 195            Pending
# 196           Accepted
# 197            Pending
# 198           Accepted
# 199           Accepted
#
# [200 rows x 5 columns]

# %%
experience_maping = {
                        "Fresher" :  0,
                        "1 Year" :   1,
                        "2 Years" :  2,
                        "3 Years" :  3,
                        "4 Years" :  4,
                        "5+ Years":  5
}

# %%
#apply job maping
std["Experience"] = std["Experience"].map(experience_maping)
jobs['Experience_Level'] = jobs["Experience_Level"].map(experience_maping)

#Makes it easier to compare student experience with job requirements

# %%
#convert text based skill into numerical formation 
#we use tf-idf vectorization of the skils
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
std_skills_matrix = vectorizer.fit_transform(std['Skills'])
job_skills_matrix = vectorizer.fit_transform(jobs['Required_Skills'])

# %%
#now create common matrix for vectorizer to use help of cosine function
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = cosine_similarity(std_skills_matrix,job_skills_matrix)

# %%
def recommend_students(job_id,top_n = 5):
    #top_n = 5 best matched students for the job
    job_idx = jobs[jobs['Job_ID']==job_id].index[0]
    similarity_scores = similarity_matrix[:, job_idx]
    """The similarity_matrix contains cosine similarity scores for every student-job combination.
Extracts the column for the specific job to get similarity scores for all students"""

    # Add Similarity Scores to the Students DataFrame
    std["Match_Score"] = similarity_scores
    #Creates a new column "Match_Score" in students_df.
    #Each student gets their similarity score with the selected job.


    #now it is time to filteration eligable  students 
    eligable_students = std[std['Experience'] >= jobs.loc[job_id,'Experience_Level']]

    #Sort Students by Best Match Score & Return Top N
    return eligable_students.sort_values(by="Match_Score", ascending=False).head(top_n)
    #Sorts eligible students by "Match_Score" in descending order (highest similarity first).
    #Returns top_n best-matched students (default 5).

# %%
job_id = 3  # Example job ID
recommended_students = recommend_students(job_id)
print(recommended_students[["Name", "Skills", "Experience", "Match_Score"]])
# Out:
#             Name                                             Skills  \
# 60   Ananya Iyer             Machine Learning, C++, Web Development
# 46  Aarav Sharma  Web Development, Cloud Computing, SQL, Machine...
# 57     Amit Iyer  Cloud Computing, Machine Learning, Web Develop...
# 94    Neha Reddy  Web Development, DevOps, Data Science, Machine...
# 20    Neha Patel                   C++, Cybersecurity, DevOps, Java
#
#     Experience  Match_Score
# 60         0.0     0.730698
# 46         0.0     0.572807
# 57         0.0     0.564606
# 94         0.0     0.544497
# 20         0.0     0.000000

# %%
with open("model.pkl", "wb") as f:
    pickle.dump((vectorizer, similarity_matrix, std, jobs), f)
